# %% [markdown]
# # Problema
#
# - Passo 1: Buscar dados dos valores das ações de fomra automática no site do Yahoo Finanças
# - Passo 2: Gerar as análises solicitadas pelo gestor de forma automática
# - Passo 3: Enviar um email automaticamente para o gestor com os resultados das análises

# %% [markdown]
# # Passo 1

# %%
# !pip install yfinance --upgrade --no-cache-dir

# %%
import yfinance

# %%
ticker = input("Digite a sigla da ação desejada: ")
dados = yfinance.Ticker(ticker).history("6mo")
fechamento = dados.Close
fechamento.plot()
# Out:
# Digite a sigla da ação desejada: ETH-USD
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Passo 2
#
# Análises dos últimos 6 meses :
#
# - Cotação maxima
# - Cotação minima
# - Cotação atual

# %% [markdown]
# maxima = fechamento.max()
# minima = fechamento.min()
# atual = fechamento[-1]

# %% [markdown]
# # Passo 3
#
# - abrir uma nova aba e digitar o endereço de gmail
# - clicar no botão Escrever
# - preencher o email do destinatario
# - preencher o assunto
# - escrever o e-mail
# - clicar em enviar

# %%
# !pip install pyautogui
# Out:
# ...
#      ---------------------------------------- 59.0/59.0 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
# !pip install pyperclip

# %%
import pyautogui

# %%
import pyperclip

# %%
pyautogui.PAUSE = 2
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")
pyautogui.click(x=74, y=167)

pyautogui.PAUSE = 2
pyautogui.click(x=1282, y=486)
pyperclip.copy("vieiranetoorlando@gmail.com")
pyautogui.PAUSE = 1
pyautogui.hotkey("ctrl", "v")
pyautogui.PAUSE = 1
pyautogui.hotkey("tab")

pyautogui.PAUSE = 2
pyperclip.copy("Análises diárias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

pyautogui.PAUSE = 2
mensagem = f"""
Prezado Gestor, 

seguem as análises dos últimos seis meses da ação: {ticker}:

Cotação máxima: R$ {round(maxima, 2)}
Cotação minima: R$ {round(minima, 2)}
Cotação atual: R$ {round(atual, 2)}
"""
    
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")
pyautogui.PAUSE = 2
pyautogui.click(x=1252, y=1005)

# %%
import time

time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1282, y=486)
